# %% [markdown]
# %md
# #### Since in this section Synthesizing Executive Business Insights, we can only upload 1 file. So we are adding screenshots and other asked content here in these cells itself.

# %% [markdown]
# ### Screenshot of primeins.gold.ai_business_insights in Unity Catalog with rows visible
#
# #### Screenshot of Claims Performance Overview
#
# ##### a. Screenshot of Claims Performance Overview
# ![image_1774611556437.png](./image_1774611556437.png "image_1774611556437.png")
# ##### b. Screenshot of Claims Performance Overview
# ![image_1774611650993.png](./image_1774611650993.png "image_1774611650993.png")
# ##### c. Screenshot of Claims Performance Overview
# ![image_1774611684237.png](./image_1774611684237.png "image_1774611684237.png")
#
#
# #### Screenshot of Customer Profile Overview
#
# ##### a. Screenshot of Customer Profile Overview
# ![image_1774611822878.png](./image_1774611822878.png "image_1774611822878.png")
# ##### b. Screenshot of Customer Profile Overview
# ![image_1774611946792.png](./image_1774611946792.png "image_1774611946792.png")
# ##### c. Screenshot of Customer Profile Overview
# ![image_1774611905005.png](./image_1774611905005.png "image_1774611905005.png")
#
#
# #### Screenshot of Policy Portfolio Overview
#
# ##### a. Screenshot of Policy Portfolio Overview
# ![image_1774612166780.png](./image_1774612166780.png "image_1774612166780.png")
# ##### b. Screenshot of Policy Portfolio Overview
# ![image_1774612201270.png](./image_1774612201270.png "image_1774612201270.png")
# ##### c. Screenshot of Policy Portfolio Overview
# ![image_1774612331620.png](./image_1774612331620.png "image_1774612331620.png")

# %% [markdown]
# ### Sample output: paste or screenshot 1 full executive summary (any domain)
#
# ### Ans:
# ####  Full executive summary = claims_performance
#
# Query:
# `SELECT
#   domain_name,
#   summary_title,
#   executive_summary
# FROM primeinsurance.gold.ai_business_insights
# WHERE domain_name = 'claims_performance'
# LIMIT 1;
# `
#
# Result:
#
# domain_name	summary_title	executive_summary
# claims_performance	Claims Performance Overview	"**Executive Summary – Claims KPI Review**
#
# | KPI | Value | Benchmark / Insight |
# |-----|-------|---------------------|
# | **Total Claims** | 227 | Modest volume – allows detailed review |
# | **Total Claim Amount** | $2,798,325 | Avg. $12,327 per claim |
# | **Avg. Claim Amount** | $12,327 | Above industry average for similar lines |
# | **Avg. Processing Time** | 2.95 days | Fast turnaround, but may mask incomplete reviews |
# | **Rejection Rate** | **38.8 %** | **Anomaly – far above typical 10‑15 %** |
# | **Major Severity %** | 25.6 % | High proportion of severe claims |
# | **Avg. Vehicles Involved** | 1.73 | Indicates multi‑vehicle incidents are common |
# | **Avg. Bodily Injuries** | 1.09 | One injury per claim on average |
# | **Police Report %** | **31.3 %** | **Anomaly – low capture rate** |
#
# ---
#
# ### Key Insights
#
# 1. **High Rejection Rate**
#    - 38.8 % of claims are rejected, suggesting either overly stringent criteria or a high incidence of fraud/false reporting.
#    - This rate is likely inflating administrative costs and eroding customer trust.
#
# 2. **Low Police Report Capture**
#    - Only 31 % of claims have an accompanying police report, which is a critical evidence source for validating claim severity and reducing fraud.
#    - The low capture rate may be contributing to the high rejection rate and the elevated average claim amount.
#
# 3. **Elevated Claim Severity**
#    - 25.6 % of claims are classified as major severity, and the average number of vehicles involved (1.73) and bodily injuries (1.09) confirm a high‑risk portfolio.
#    - This drives the average claim amount upward and increases exposure.
#
# 4. **Rapid Processing Time**
#    - 2.95 days is commendably fast, but the combination of high rejection and low evidence suggests the speed may come at the expense of thoroughness.
#
# ---
#
# ### Risks
#
# | Risk | Impact | Likelihood |
# |------|--------|------------|
# | **Fraud Exposure** | High claim payouts, regulatory scrutiny | Medium‑High |
# | **Customer Attrition** | Rejections and lack of transparency | Medium |
# | **Operational Overhead** | Re‑work on rejected claims, appeals | Medium |
# | **Reputation Damage** | Perceived unfairness, negative reviews | Low‑Medium |
#
# ---
#
# ### Recommendations
#
# 1. **Revise Rejection Criteria**
#    - Conduct a root‑cause analysis of rejected claims.
#    - Tighten only the most egregious fraud indicators; consider a “pre‑review” step to flag borderline cases for human review.
#
# 2. **Improve Police Report Capture**
#    - Automate prompts for policyholders to upload police reports at the time of claim filing.
#    - Partner with local law‑enforcement portals to pull reports directly where possible.
#
# 3. **Enhance Evidence‑Based Triage**
#    - Deploy AI‑driven triage tools that weigh evidence quality (photos, police reports, witness statements) before deciding on acceptance or rejection.
#    - Use the triage score to flag high‑severity, high‑risk claims for expedited human review.
#
# 4. **Targeted Training for Claims Adjusters**
#    - Focus on interpreting severity indicators and evidence thresholds.
#    - Emphasize the importance of evidence capture and documentation.
#
# 5. **Monitor Fraud Indicators**
#    - Implement a fraud‑risk score that updates in real time as new evidence is added.
#    - Flag claims with low police‑report coverage and high severity for additional scrutiny.
#
# 6. **Customer Communication Protocol**
#    - Provide clear, transparent explanations for rejections and next‑step options.
#    - Offer a streamlined appeal process to reduce churn.
#
# 7. **Benchmarking & Continuous Improvement**
#    - Track the same KPIs quarterly and compare against industry peers.
#    - Set realistic targets: reduce rejection rate to <20 %, increase police report capture to >70 %, and maintain processing time ≤3 days.
#
# ---
#
# **Bottom Line:**
# The portfolio is exposed to higher-than‑expected claim amounts and a high rejection rate, largely driven by insufficient evidence capture (police reports). By tightening evidence requirements, improving triage, and refining rejection criteria, the organization can reduce fraud exposure, lower administrative costs, and improve customer satisfaction while maintaining rapid claim processing.

# %% [markdown]
# ### Sample output: 2 ai_query() SQL results
#
# #### Ans- 1st ai_qyery() result :
# `%sql
# SELECT
#   ai_query(
#     'databricks-gpt-oss-20b',
#     'What does a high claim rejection rate indicate in insurance?'
#   ) AS explanation;`
#
# A high claim‑rejection rate in an insurance portfolio is a red flag that something in the underwriting‑to‑claims chain is not working as intended. It can point to several underlying issues:
#
# | What the high rate may signal | Why it matters | Typical causes |
# |------------------------------|----------------|----------------|
# | **Aggressive fraud detection** | Protects the insurer’s bottom line, but can backfire if legitimate claims are flagged. | Over‑tight fraud rules, automated systems that misclassify claims, lack of human review. |
# | **Poor underwriting quality** | Policies are sold to risk profiles that are too high for the premiums charged. | Inadequate risk assessment, outdated underwriting guidelines, insufficient data. |
# | **Misaligned policy terms** | Policyholders misunderstand coverage, leading to claims that are technically out of scope. | Ambiguous wording, frequent changes to terms, inadequate disclosure. |
# | **Claims‑processing inefficiencies** | Delays and errors increase rejection rates and erode customer trust. | Manual bottlenecks, lack of training, outdated technology. |
# | **High‑risk portfolio** | The insurer is knowingly taking on risk that is hard to cover. | Targeted niche markets, aggressive growth strategies, insufficient pricing. |
# | **Regulatory or compliance pressure** | Stricter rules force more denials to avoid penalties. | New solvency or consumer‑protection regulations. |
#
# ### Why it matters
# - **Financial impact** – A high rejection rate can reduce claim payouts, but it can also hurt revenue if policyholders cancel or switch carriers.
# - **Reputation risk** – Customers who feel unfairly denied may spread negative word‑of‑mouth, damaging brand equity.
# - **Regulatory scrutiny** – Persistent denials can trigger investigations or fines if they appear discriminatory or arbitrary.
#
# ### What to do
# 1. **Audit the claims data** – Identify patterns (e.g., specific lines of business, geographic areas, or claim types) that drive rejections.
# 2. **Review underwriting guidelines** – Ensure they match current risk profiles and market conditions.
# 3. **Improve communication** – Provide clear, timely explanations to policyholders about why a claim was denied and how to appeal.
# 4. **Invest in technology** – Use data analytics and AI to flag only truly suspicious claims, reducing false positives.
# 5. **Train staff** – Equip underwriters and claims adjusters with the latest risk assessment tools and customer‑service skills.
# 6. **Monitor regulatory changes** – Stay ahead of new compliance requirements that could affect denial criteria.
#
# In short, a high claim rejection rate is a symptom of deeper operational, underwriting, or market‑risk issues. Addressing it requires a balanced approach that protects the insurer’s financial health while maintaining fair, transparent treatment of policyholders.
#
#
# #### Ans- 2nd ai_qyery() result :
#
# `%sql
# SELECT
#   ai_query(
#     'databricks-gpt-oss-20b',
#     CONCAT(
#       'Explain business impact of average claim amount: ',
#       CAST(AVG(injury + property + vehicle) AS STRING)
#     )
#   ) AS explanation
# FROM primeinsurance.gold.fact_claims;
# `
#
# **Average Claim Amount (≈ $12,327.42)**
# *What it means for the business*
#
# | Area | Impact of a $12k average claim | Why it matters |
# |------|--------------------------------|----------------|
# | **Profitability** | Higher average claims raise the loss ratio (claims ÷ earned premiums). If the loss ratio climbs above target, underwriting profit shrinks or turns negative. | Directly reduces net income and shareholder returns. |
# | **Pricing & Underwriting** | To keep the loss ratio in line, premiums may need to be increased or underwriting criteria tightened. | Ensures the product remains financially viable and competitive. |
# | **Reserves & Cash Flow** | Larger claims require larger loss‑reserve provisions and more immediate cash outlays. | Affects liquidity, working‑capital needs, and solvency ratios. |
# | **Capital & Solvency** | Higher claim amounts increase the risk‑adjusted capital required (e.g., under Solvency II or IFRS 17). | Impacts regulatory capital, cost of capital, and ability to write new business. |
# | **Reinsurance** | A higher average claim may push the company to purchase more or higher‑limit reinsurance to cap exposure. | Alters the cost structure and risk‑transfer strategy. |
# | **Product Design** | If the average claim approaches or exceeds policy limits, the product may need redesign (e.g., higher limits, new riders). | Keeps the product attractive while managing risk. |
# | **Claims Management** | A high average claim can signal inefficiencies in claims handling or emerging loss trends. | Drives investment in claims technology, fraud detection, and loss‑control programs. |
# | **Risk Appetite & Strategy** | The average claim informs the risk appetite framework—whether the company is comfortable with high‑severity, low‑frequency risks. | Guides portfolio mix, diversification, and strategic focus. |
# | **Competitive Positioning** | Competitors with lower average claims may offer lower premiums or better coverage terms. | Influences market share and brand perception. |
#
# **Key Take‑aways**
#
# 1. **Monitor the trend** – A rising average claim signals emerging risks or pricing gaps that need addressing.
# 2. **Adjust pricing or underwriting** – If the average claim is above industry benchmarks, consider premium hikes or stricter underwriting.
# 3. **Re‑evaluate reinsurance** – Higher average claims may justify additional or higher‑limit reinsurance to protect capital.
# 4. **Invest in loss prevention** – Target high‑severity loss categories with prevention programs to reduce the average claim size.
# 5. **Use it for forecasting** – Combine the average claim with claim frequency to project future losses, set reserves, and plan capital.
#
# In short, an average claim of ~$12,327 is a critical lever that influences profitability, pricing, capital, and risk management. Keeping it in check—or understanding why it’s high—helps maintain a healthy, competitive insurance portfolio.

# %%
# Databricks Notebook Setup

from pyspark.sql import functions as F
from datetime import datetime
import json

# %%
# Load gold tables from primeinsurance database into Spark DataFrames
claims_df = spark.table("primeinsurance.gold.fact_claims")
policy_df = spark.table("primeinsurance.gold.dim_policy")
customer_df = spark.table("primeinsurance.gold.dim_customer")
car_df = spark.table("primeinsurance.gold.dim_car")
sales_df = spark.table("primeinsurance.gold.fact_sales")

# %%
# Calculate claims KPIs from claims_df
claims_kpi = claims_df.select(
    F.count("*").alias("total_claims"),  # Total number of claims
    F.avg(F.col("injury") + F.col("property") + F.col("vehicle")).alias("avg_claim_amount"),  # Average claim amount
    F.sum(F.col("injury") + F.col("property") + F.col("vehicle")).alias("total_claim_amount"),  # Total claim amount
    F.avg("processing_time_days").alias("avg_processing_time"),  # Average processing time in days
    (F.sum(F.when(F.col("claim_rejected") == True, 1).otherwise(0)) * 100.0 / F.count("*")).alias("rejection_rate"),  # Claim rejection rate (%)
    (F.sum(F.when(F.col("incident_severity") == "Major Damage", 1).otherwise(0)) * 100.0 / F.count("*")).alias("major_severity_pct"),  # % of claims with major severity
    F.avg("number_of_vehicles_involved").alias("avg_vehicles_involved"),  # Average number of vehicles involved per claim
    F.avg("bodily_injuries").alias("avg_bodily_injuries"),  # Average bodily injuries per claim
    (F.sum(F.when(F.col("police_report_available") == True, 1).otherwise(0)) * 100.0 / F.count("*")).alias("police_report_pct")  # % of claims with police report available
)

# Convert KPIs to JSON for downstream use
claims_kpi_dict = claims_kpi.toPandas().to_dict(orient="records")[0]
claims_kpi_json = json.dumps(claims_kpi_dict)

# %%
# Calculate policy KPIs from policy_df joined with claims_df
policy_join_df = policy_df.join(claims_df, "policy_id", "left")

policy_kpi = policy_join_df.select(
    F.countDistinct("policy_id").alias("total_policies"),  # Total number of policies
    F.avg("policy_annual_premium").alias("avg_premium"),  # Average annual premium
    F.sum("umbrella_limit").alias("total_umbrella_coverage"),  # Total umbrella coverage
    F.avg("policy_deductable").alias("avg_deductible"),  # Average deductible
    (F.sum(F.when(F.col("claim_id").isNotNull(), 1).otherwise(0)) * 100.0 / F.countDistinct("policy_id")).alias("policies_with_claim_pct")  # % of policies with at least one claim
)

policy_kpi_dict = policy_kpi.toPandas().to_dict(orient="records")[0]
policy_kpi_json = json.dumps(policy_kpi_dict)

# %%
# Calculate customer KPIs from customer_df joined with claims_df
customer_join_df = customer_df.join(claims_df, "customer_id", "left")

customer_kpi = customer_join_df.select(
    F.countDistinct("customer_id").alias("total_customers"),  # Total number of customers
    F.avg("balance").alias("avg_balance"),  # Average customer balance
    (F.sum(F.when(F.col("default_flag") == 1, 1).otherwise(0)) * 100.0 / F.count("*")).alias("default_rate"),  # Default rate (%)
    F.avg(F.when(F.col("claim_id").isNotNull(), 1).otherwise(0)).alias("claims_per_customer"),  # Average claims per customer
    (F.sum(F.when(F.col("CarLoan") == 1, 1).otherwise(0)) * 100.0 / F.count("*")).alias("car_loan_pct"),  # % of customers with car loan
    (F.sum(F.when(F.col("HHInsurance") == 1, 1).otherwise(0)) * 100.0 / F.count("*")).alias("home_insurance_pct")  # % of customers with home insurance
)

# Convert KPIs to JSON for downstream use
customer_kpi_dict = customer_kpi.toPandas().to_dict(orient="records")[0]
customer_kpi_json = json.dumps(customer_kpi_dict)

# %%
def build_prompt(domain, kpi_json):
    # Build prompt for insurance executive summary generation
    # Returns a formatted prompt string for AI executive summary based on domain and KPI JSON
    return f"""
You are a senior insurance business analyst.

Domain: {domain}

Given the following KPI summary:
{kpi_json}

Write an executive summary that includes:
- Key insights
- Risks
- Opportunities
- Any anomalies

Keep it concise and decision-focused.
"""

# %%
# Create a temporary view for policy KPIs as JSON for downstream use
spark.sql(f"""
CREATE OR REPLACE TEMP VIEW policy_kpi_view AS
SELECT '{policy_kpi_json}' AS kpi_json
""")

# %%
# Create a temporary view for claims KPIs as JSON for downstream use
spark.sql(f"""
CREATE OR REPLACE TEMP VIEW claims_kpi_view AS
SELECT '{claims_kpi_json}' AS kpi_json
""")

# %%
# Create a temporary view for customer KPIs as JSON for downstream use
spark.sql(f"""
CREATE OR REPLACE TEMP VIEW customer_kpi_view AS
SELECT '{customer_kpi_json}' AS kpi_json
""")

# %%
# %sql
-- Combine KPI JSON views for policy, claims, and customer domains
SELECT * FROM policy_kpi_view
union all
SELECT * FROM claims_kpi_view
union all
SELECT * FROM customer_kpi_view;

# %%
# %sql
-- Create a temporary view for claims executive summary using AI
CREATE OR REPLACE TEMP VIEW claims_summary_view AS
SELECT 
  'claims_performance' AS domain_name,
  'Claims Performance Overview' AS summary_title,

  ai_query(
    'databricks-gpt-oss-20b',
    CONCAT(
      'You are a senior insurance executive advisor. ',
      'Analyze the KPI JSON and produce a concise executive summary with insights, risks, and recommendations. ',
      'Highlight anomalies if any: ',
      kpi_json
    )
  ) AS executive_summary,

  kpi_json,
  current_timestamp() AS generation_timestamp,
  'databricks-gpt-oss-20b' AS model_name,
  'SUCCESS' AS status

FROM claims_kpi_view;

# %%
# %sql
-- Create a temporary view for customer executive summary using AI
CREATE OR REPLACE TEMP VIEW customer_summary_view AS
SELECT 
  'customer_profile' AS domain_name,
  'Customer Profile Overview' AS summary_title,

  ai_query(
    'databricks-gpt-oss-20b',
    CONCAT(
      'You are a senior insurance executive advisor. ',
      'Analyze the KPI JSON and produce a concise executive summary with insights, risks, and recommendations. ',
      'Highlight customer risk segments and opportunities: ',
      kpi_json
    )
  ) AS executive_summary,

  kpi_json,
  current_timestamp() AS generation_timestamp,
  'databricks-gpt-oss-20b' AS model_name,
  'SUCCESS' AS status

FROM customer_kpi_view;

# %%
# %sql
-- Create a temporary view for policy executive summary using AI
CREATE OR REPLACE TEMP VIEW policy_summary_view AS
SELECT 
  'policy_portfolio' AS domain_name,
  'Policy Portfolio Overview' AS summary_title,

  ai_query(
    'databricks-gpt-oss-20b',
    CONCAT(
      'You are a senior insurance executive advisor. ',
      'Analyze the KPI JSON and produce a concise executive summary with insights, risks, and recommendations: ',
      kpi_json
    )
  ) AS executive_summary,

  kpi_json,
  current_timestamp() AS generation_timestamp,
  'databricks-gpt-oss-20b' AS model_name,
  'SUCCESS' AS status

FROM policy_kpi_view;

# %%
# %sql
-- Table to store AI-generated business insights summaries for insurance domains
CREATE TABLE IF NOT EXISTS primeinsurance.gold.ai_business_insights (
  domain_name STRING,           -- Domain of the summary (e.g., claims, policy, customer)
  summary_title STRING,         -- Title of the executive summary
  executive_summary STRING,     -- AI-generated executive summary text
  kpi_json STRING,              -- KPI metrics in JSON format
  generation_timestamp TIMESTAMP,-- Timestamp when summary was generated
  model_name STRING,            -- Name of the AI model used
  status STRING                 -- Status of the summary generation
);

# %%
# %sql
-- Insert AI-generated executive summaries for claims, policy, and customer domains into gold insights table
INSERT INTO primeinsurance.gold.ai_business_insights
SELECT * FROM (
  -- Claims
  SELECT * FROM claims_summary_view
  UNION ALL
  -- Policy
  SELECT * FROM policy_summary_view
  UNION ALL
  -- Customer
  SELECT * FROM customer_summary_view
);

# %%
# %sql
truncate table primeinsurance.gold.ai_business_insights;

# %%
# %sql
-- Retrieve all AI-generated business insights summaries for insurance domains
SELECT * 
FROM primeinsurance.gold.ai_business_insights;

# %%
# %sql
-- Use AI to explain implications of a high claim rejection rate in insurance
SELECT 
  ai_query(
    'databricks-gpt-oss-20b',
    'What does a high claim rejection rate indicate in insurance?'
  ) AS explanation;

# %%
# %sql
-- Use AI to explain the business impact of the average claim amount in insurance
SELECT 
  ai_query(
    'databricks-gpt-oss-20b',
    CONCAT(
      'Explain business impact of this average claim amount: ',
      CAST(AVG(injury + property + vehicle) AS STRING)
    )
  ) AS explanation
FROM primeinsurance.gold.fact_claims;

# %%
# %sql
SELECT 
  domain_name,
  summary_title,
  executive_summary
FROM primeinsurance.gold.ai_business_insights
WHERE domain_name = 'claims_performance'
LIMIT 1;

# %%
# %sql
SELECT 
  ai_query(
    'databricks-gpt-oss-20b',
    'What does a high claim rejection rate indicate in insurance?'
  ) AS explanation;

# %%
# %sql
SELECT 
  ai_query(
    'databricks-gpt-oss-20b',
    CONCAT(
      'Explain business impact of average claim amount: ',
      CAST(AVG(injury + property + vehicle) AS STRING)
    )
  ) AS explanation
FROM primeinsurance.gold.fact_claims;
