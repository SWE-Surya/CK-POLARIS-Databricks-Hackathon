# %%
# %sql
CREATE TABLE IF NOT EXISTS primeinsurance.silver.dq_issues (
    issue_id STRING,
    table_name STRING,
    column_name STRING,
    issue_description STRING,
    severity STRING,
    affected_record STRING,
    detected_at TIMESTAMP
);
